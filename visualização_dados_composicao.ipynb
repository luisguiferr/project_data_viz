# %% [markdown]
# # Paleta de cores

# %% [markdown]
# Referência das cores

# %% [markdown]
# |Azul||||||
# |------|------|------|------|------|------|
# | AZUL1 |AZUL2 |AZUL3 |AZUL4 |AZUL5 |AZUL6 |
# |#174A7E | #4A81BF | #6495ED| #2596be | #94AFC5 | #CDDBF3 |
# |![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/AZUL1.png?raw=true)|![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/AZUL2.png?raw=true)|![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/AZUL3.png?raw=true)|![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/AZUL4.png?raw=true)|![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/AZUL5.png?raw=true)|![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/AZUL6.png?raw=true) |
#
# &nbsp;
#
# |Cinza||||||
# |------|------|------|------|------|------|
# | CINZA1 |CINZA2 |CINZA3 |CINZA4 |CINZA5|BRANCO|
# |#231F20 | #414040| #555655 | #A6A6A5| #BFBEBE |#FFFFFF|
# | ![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/CINZA1.png?raw=true)  |![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/CINZA2.png?raw=true) |![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/CINZA3.png?raw=true) |![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/CINZA4.png?raw=true) |![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/CINZA5.png?raw=true)|![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/BRANCO.png?raw=true)|
#
# &nbsp;
#
# |Vermelho|||Verde|||
# |------|------|------|------|------|------|
# | VERMELHO1 |VERMELHO2 |LARANJA1 | VERDE1 |VERDE2 | VERDE3 |
# |#C3514E | #E6BAB7 | #F79747|#0C8040 | #9ABB59 |#9ECCB3|
# | ![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores//VERMELHO1.png?raw=true) |![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/VERMELHO2.png?raw=true)|![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/LARANJA1.png?raw=true)| ![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/VERDE1.png?raw=true) |![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/VERDE2.png?raw=true)|![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/VERDE3.png?raw=true)|

# %%
# Definindo a paleta de cores
AZUL1, AZUL2, AZUL3, AZUL4, AZUL5, AZUL6 = '#174A7E', '#4A81BF', "#6495ED", '#2596BE', '#94AFC5', '#CDDBF3'
CINZA1, CINZA2, CINZA3, CINZA4, CINZA5, BRANCO = '#231F20', '#414040', '#555655', '#A6A6A5', '#BFBEBE', '#FFFFFF'
VERMELHO1, VERMELHO2, LARANJA1 = '#C3514E',	'#E6BAB7',	'#F79747'
VERDE1, VERDE2, VERDE3 = '#0C8040',	'#9ABB59', '#9ECCB3'

# %% [markdown]
# # Bibliotecas

# %%
# Importação das bibliotecas
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from matplotlib import transforms

# %% [markdown]
# # Conhecendo os dados

# %%
# Importando a base de dados com o PIB dos estados brasileiros de 2002 a 2020
df_pib = pd.read_csv('https://raw.githubusercontent.com/alura-cursos/dataviz-graficos-composicao-relacionamento/refs/heads/main/dados/pib_br_2002_2020_estados.csv')
df_pib
# Out:
#       ano sigla_uf        regiao           pib  impostos_liquidos  \
# 0    2002       RO         Norte    7467629886          839731192
# 1    2003       RO         Norte    9425010486         1108434936
# 2    2004       RO         Norte   11004641436         1288806654
# 3    2005       RO         Norte   12511821181         1476144194
# 4    2006       RO         Norte   13054713344         1613809974
# ..    ...      ...           ...           ...                ...
# 508  2016       DF  Centro-Oeste  235540044811        29145619376
# 509  2017       DF  Centro-Oeste  244722249337        29120461647
# 510  2018       DF  Centro-Oeste  254817204692        28692287369
# 511  2019       DF  Centro-Oeste  273613711477        30686607647
# 512  2020       DF  Centro-Oeste  265847334003        25466227775
#
#                va  va_agropecuaria  va_industria   va_servicos    va_adespss
# 0      6627898698        715526872    1191090432    2484579193    2236702207
# ...

# %%
# Tipos de dados
df_pib.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513 entries, 0 to 512
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ano                513 non-null    int64
#  1   sigla_uf           513 non-null    object
#  2   regiao             513 non-null    object
#  3   pib                513 non-null    int64
#  4   impostos_liquidos  513 non-null    int64
#  5   va                 513 non-null    int64
#  6   va_agropecuaria    513 non-null    int64
#  7   va_industria       513 non-null    int64
#  8   va_servicos        513 non-null    int64
#  9   va_adespss         513 non-null    int64
# dtypes: int64(8), object(2)
# memory usage: 40.2+ KB

# %% [markdown]
# ### Dicionário

# %% [markdown]
# `ano`: ano de representação dos dados
#
# `sigla_uf`: sigla do Estado representada na base de dados
#
# `regiao`: região do Estado
#
# `pib`: valor do PIB do Estado
#
# `impostos_liquidos`: impostos líquidos do Estado
#
# `va`: valor adicionado bruto a preços correntes das atividades econômicas
#
# `va_agropecuaria`: valor adicionado bruto a preços correntes da agropecuária
#
# `va_industria`: valor adicionado bruto a preços correntes da indústria
#
# `va_servicos`: valor adicionado bruto a preços correntes dos serviços, exclusive
# administração, defesa, educação e saúde públicas e seguridade social
#
# `va_adespss`: valor adicionado bruto a preços correntes da administração, defesa, educação e saúde públicas e seguridade social

# %% [markdown]
# ### Questionamentos

# %% [markdown]
# 1. Como está disposto o PIB nos Estados brasileiros no ano de 2020? É possível notar os Estados com maior e menor participação no PIB nacional?
#
# 2. Houve uma significativa mudança na distribuição do PIB por região comparando os valores de 2002 e 2020?
#
# 3. Qual a participação do Estado de Minas Gerais no PIB de todo o Brasil no ano de 2020?
#
# 4. Como está distribuído o PIB do Estado da Bahia em 2020 separado por impostos líquidos e os valores adicionados brutos dos bens e serviços produzidos?
#
# 5. Qual a evolução anual do PIB do Estado do Rio de Janeiro entre os anos de 2010 a 2020?
#
# 6. Como está distribuído o PIB nos 3 últimos quinquênios (lustro) dos dados (2010, 2015, 2020) na Região Sul do Brasil divididos pelos Estados (Paraná, Santa Catarina e Rio Grande do Sul)?
#
# 7. Como estão distribuídos, em porcentagem, os valores adicionados de bens e serviços descritos na base de dados em relação a cada região no ano de 2020?
#
# 8. Na agropecuária, como estão distribuídos seus valores adicionados por região dentro do período da base dos dados (2002 - 2020)?

# %% [markdown]
# # Análise 1

# %% [markdown]
# Como está disposto o PIB nos Estados brasileiros no ano de 2020? É possível notar os Estados com maior e menor participação no PIB nacional?

# %% [markdown]
# ### Tratando os dados

# %%
# Criação de df com os dados desejados
df_pib_2020 = df_pib.copy()
df_pib_2020 = df_pib_2020.query('ano == 2020').set_index('sigla_uf').sort_values('pib',ascending=False)[['pib']]

df_pib_2020.head()
# Out:
#                     pib
# sigla_uf
# SP        2377638979835
# RJ         753823710636
# MG         682786116407
# PR         487930593779
# RS         470941846057

# %% [markdown]
# ### Gerando gráfico de pizza

# %%
# Geração de gráfico com os parâmetros para a visualização dos dados
fig, ax = plt.subplots(figsize=(6,6))
ax.pie(data=df_pib_2020, x='pib', labels=df_pib_2020.index, autopct='%.1f%%',
       radius=1.1, pctdistance=0.8, textprops={'size':12})

# Personalização do gráfico
plt.suptitle('Produto Interno Bruto (PIB) por estado (2020)', size=18, color=CINZA1)
plt.title('Em porcentagem (%)', fontsize=14, color=CINZA3, pad=15, x=0.09, y=0.99)

# Anotações do gráfico
ax.text(1.1, 0.3,
        'Um $\\bf{gráfico\\;de\\;pizza}$, consegue trazer a informação de\n'
        'participação no PIB de forma direta, no entanto, percebemos\n'
        'que o uso de $\\bf{muitas\\;fatias}$ atrapalham na análise dos\n'
        'dados para estados com $\\bf{menor}$ parcela no PIB.\n'
        'Além de gerar incômodo visualmente para quem lê.\n\n'
        'Percebemos que os estados de $\\bf{São\\;Paulo}$, $\\bf{Rio\\;de\\;Janeiro}$ e\n'
        '$\\bf{Minas\\;Gerais}$ possuem $\\bf{maior}$ participação no PIB nacional,\n'
        'porém, não conseguimos precisar quais estados tem a menor\n'
        'e quanto seria em percentual.',
        fontsize=12,
        linespacing=1.45,
        color=CINZA3, transform= ax.transAxes)

plt.show()

# %% [markdown]
# ### Ajustando a visualização para vários dados (treemap)

# %%
# Criando df com os dados desejados
pib_2020 = df_pib.copy()
pib_2020 = pib_2020.query('ano == 2020')[['regiao', 'sigla_uf', 'pib']]

# Ajustando os valores do PIB para bilhões e ordenando
pib_2020['pib'] = round(pib_2020['pib'] / 1e9, 0).astype('int64')
pib_2020 = pib_2020.sort_values('pib', ascending=False)

# Gerando coluna para a porcentagem da representação de cada estado no PIB
pib_2020['pib_%'] = pib_2020['pib'].div(pib_2020['pib'].sum(), axis=0)
pib_2020['pib_%'] = round(pib_2020['pib_%'] * 100, 2)

pib_2020.head()
# Out:
#       regiao sigla_uf   pib  pib_%
# 379  Sudeste       SP  2378  31.25
# 360  Sudeste       RJ   754   9.91
# 322  Sudeste       MG   683   8.98
# 398      Sul       PR   488   6.41
# 436      Sul       RS   471   6.19

# %%
# Gerando o gráfico de árvore (TREEMAP)
fig = px.treemap(pib_2020, path=[px.Constant('Distribuição do PIB'), 'sigla_uf'],
                 values='pib_%',
                 color='regiao',
                 custom_data=['regiao', 'pib', 'pib_%'],
                 title='Distribuição do PIB nos estados brasileiros no ano de 2020 (em bilhões de reais)',
                 color_discrete_map={'(?)': BRANCO,
                                     'Sudeste':AZUL3,
                                     'Sul': LARANJA1,
                                     'Nordeste': AZUL5,
                                     'Centro-Oeste': VERDE1,
                                     'Norte': CINZA5})

# Ajustando o layout do gráfico
fig.update_layout(width=1400, height=600, margin=dict(t=50, l=0, r=0, b=25),
                  font_family='Arial',
                  font_size=14,
                  font_color=CINZA2,
                  title_font_color=CINZA1,
                  title_font_size=24)

fig.update_traces(marker=dict(cornerradius=5), texttemplate='<b>%{label}</b>',
                  hovertemplate='<b>Estado:</b> %{label}<br>'
                  '<b>Região</b> = %{customdata[0]}<br>'
                  '<b>PIB</b> = %{customdata[1]} (em bilhões)<br>'
                  '<b>Participação</b> = %{customdata[2]}%<br>')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Análise 2

# %% [markdown]
# Houve uma significativa mudança na distribuição do PIB por região comparando os valores de 2002 e 2020?

# %% [markdown]
# ### Tratando os dados

# %%
# Criação do df com os dados desejados
df_pib_2002 = df_pib.query('ano == 2002')[['regiao', 'pib']]
df_pib_2020 = df_pib.query('ano == 2020')[['regiao', 'pib']]

df_pib_2002 = df_pib_2002.groupby('regiao')[['pib']].sum().sort_values('pib', ascending=False)
df_pib_2020 = df_pib_2020.groupby('regiao')[['pib']].sum().sort_values('pib', ascending=False)

display(df_pib_2002, df_pib_2020)
# Out:
#                        pib
# regiao
# Sudeste       854309793369
# Sul           241564819092
# Nordeste      194847656440
# Centro-Oeste  128162640832
# Norte          69902366306
#                         pib
# regiao
# Sudeste       3952694729239
# Sul           1308147455374
# Nordeste      1079331030689
# Centro-Oeste   791250735824
# Norte          478173048893

# %% [markdown]
# ### Gerando gráfico de pizza

# %%
# Geração de gráfico com os parâmetros para a visualização dos dados
fig, axs = plt.subplots(1, 2, figsize=(14,6))

# Definindo as cores do gráfico
cores = [AZUL3, LARANJA1, AZUL5, VERDE1, CINZA5]

# Personalização do gráfico
plt.suptitle('Produto Interno Bruto (PIB) por região',
             fontsize=18,
             color=CINZA1,
             ha='right',
             x=0.5,
             y=1.05)

# Gráfico 1
ptc, text, _ = axs[0].pie(data=df_pib_2002, x='pib', labels=df_pib_2002.index,
                          autopct='%.1f%%',
                          pctdistance=0.6,
                          textprops={'size':12,
                                     'fontweight':'bold',
                                     'color': BRANCO},
                          colors=cores)

# Título do gráfico 1
axs[0].annotate('Em 2002', xy=(50,350), size=12, xycoords='axes points',
                bbox=dict(boxstyle='round', fc=BRANCO, ec=CINZA3))

# Ajuste das cores das regiões relativas as fatias
for i, p in enumerate(ptc):
    text[i].set_color(p.get_facecolor())

# Gráfico 2
ptc, text, _ = axs[1].pie(data=df_pib_2020, x='pib', labels=df_pib_2020.index,
                          autopct='%.1f%%',
                          pctdistance=0.6,
                          textprops={'size':12,
                                     'fontweight':'bold',
                                     'color': BRANCO},
                          colors=cores)

# Título do gráfico 2
axs[1].annotate('Em 2020', xy=(50,350), size=12, xycoords='axes points',
                bbox=dict(boxstyle='round', fc=BRANCO, ec=CINZA3))

# Ajuste das cores das regiões relativas as fatias
for i, p in enumerate(ptc):
    text[i].set_color(p.get_facecolor())

axs[0].annotate('A Região Sudeste foi a única que\nreduziu a participação no PIB',
                xy=(180, 245), xycoords='axes points', xytext=(280, 295), textcoords='axes points',
                bbox=dict(boxstyle="round", fc=BRANCO, ec=CINZA3),
                size=10, arrowprops=dict(arrowstyle="->", fc=CINZA1, connectionstyle="arc,angleA=-90,angleB=0,armA=23,armB=30,rad=5"))

axs[1].annotate('\n\n', xy=(140, 245), xycoords='axes points', xytext=(-50, 295),
                textcoords='axes points', size=10, arrowprops=dict(arrowstyle="->", fc=CINZA1, connectionstyle="arc,angleA=-90,angleB=0,armA=30,armB=-30,rad=5"))

plt.show()

# %% [markdown]
# ### Análise proposta

# %% [markdown]
# Visualização dos estados da região Sudeste, PIB dos anos de 2002 e 2020

# %%
df_sudeste = df_pib.copy()
df_sudeste_2002 = df_sudeste.query('regiao == "Sudeste" & ano == 2002')[['sigla_uf', 'pib']].set_index('sigla_uf').sort_values('pib', ascending=False)
df_sudeste_2020 = df_sudeste.query('regiao == "Sudeste" & ano == 2020')[['sigla_uf', 'pib']].set_index('sigla_uf').sort_values('pib', ascending=False)

display(df_sudeste_2002, df_sudeste_2020)
# Out:
#                    pib
# sigla_uf
# SP        518878815174
# RJ        184310915236
# MG        124071066407
# ES         27048996552
#                     pib
# sigla_uf
# SP        2377638979835
# RJ         753823710636
# MG         682786116407
# ES         138445922361

# %%
# Geração de gráfico com os parâmetros para a visualização dos dados
fig, axs = plt.subplots(1, 2, figsize=(14,6))

# Definindo as cores do gráfico
cores = [AZUL3, LARANJA1, VERDE1, CINZA5]

# Personalização do gráfico
plt.suptitle('Produto Interno Bruto (PIB) por estado na região Sudeste',
             fontsize=18,
             color=CINZA1,
             ha='right',
             x=0.68,
             y=1.05)

# Gráfico 1
ptc, text, _ = axs[0].pie(data=df_sudeste_2002, x='pib', labels=df_sudeste_2002.index,
                          autopct='%.1f%%',
                          pctdistance=0.6,
                          textprops={'size':12,
                                     'fontweight':'bold',
                                     'color':BRANCO},
                          colors=cores)

# Título do gráfico 1
axs[0].annotate('Em 2002', xy=(50,350), size=12, xycoords='axes points',
                bbox=dict(boxstyle='round', fc=BRANCO, ec=CINZA3))

# Ajuste das cores das regiões relativas as fatias
for i, p in enumerate(ptc):
    text[i].set_color(p.get_facecolor())

# Gráfico 2
ptc, text, _ = axs[1].pie(data=df_sudeste_2020, x='pib', labels=df_sudeste_2020.index,
                          autopct='%.1f%%',
                          pctdistance=0.6,
                          textprops={'size':12,
                                     'fontweight':'bold',
                                     'color':BRANCO},
                          colors=cores)

# Título do gráfico 2
axs[1].annotate('Em 2020', xy=(50,350), size=12, xycoords='axes points',
                bbox=dict(boxstyle='round', fc=BRANCO, ec=CINZA3))

# Ajuste das cores das regiões relativas as faixas
for i, p in enumerate(ptc):
    text[i].set_color(p.get_facecolor())

axs[1].text(1.05, 0.4,
            'É possível observar que, os únicos estados\n'
            'que tiveram crescimento significativo no PIB,\n'
            'foram os estados: $\\bf{Rio\\;de\\;Janeiro}$ e $\\bf{Minas\\;Gerais}$.\n'
            '\nAmbos tiveram crescimento de $\\bf{2.5\\%}$ e $\\bf{2.8\\%}$\n'
            'respetivamente.',
            fontsize=12,
            linespacing=1.45,
            color=CINZA3, transform=axs[1].transAxes)

plt.show()

# %% [markdown]
# # Análise 3

# %% [markdown]
# Qual a participação do Estado de Minas Gerais no PIB de todo o Brasil no ano de 2020?

# %% [markdown]
# ### Tratando os dados

# %%
# Criação do df com os dados desejados
df_mg_2020 = df_pib.query('ano == 2020')[['sigla_uf', 'pib']]

# Renomeação de todos os estados como 'Outros' e MG para 'Minas Gerais'
df_mg_2020.loc[df_mg_2020['sigla_uf'] == 'MG', 'sigla_uf'] = 'Minas Gerais'
df_mg_2020.loc[df_mg_2020['sigla_uf'] != 'Minas Gerais', 'sigla_uf'] = 'Outros'

# Agrupamento do df
df_mg_2020 = df_mg_2020.groupby('sigla_uf').sum()

df_mg_2020
# Out:
#                         pib
# sigla_uf
# Minas Gerais   682786116407
# Outros        6926810883612

# %% [markdown]
# ### Gerando gráfico de rosca

# %%
# Geração de gráfico com os parâmetros para a visualização dos dados
fig, ax = plt.subplots(figsize=(6,6))

# Definindo as cores do gráfico
cores = [AZUL3, CINZA5]

# Personalização do gráfico
plt.suptitle('PIB de Minas Gerais em relação ao Brasil em 2020',
             fontsize=18,
             color=CINZA1,
             ha='left',
             x=0.0,
             y=0.9)

# Gráfico de rosca
ptc, text, _ = ax.pie(data=df_mg_2020, x='pib', labels=df_mg_2020.index,
                      autopct='%.1f%%',
                      startangle=0,
                      pctdistance=0.8,
                      wedgeprops=dict(width=0.4),
                      textprops=dict(size=12,
                                     fontweight='bold',
                                     color=BRANCO),
                      colors=cores)

# Ajuste das cores das regiões relativas as fatias
for i, p in enumerate(ptc):
    text[i].set_color(p.get_facecolor())

plt.show()

# %% [markdown]
# # Análises propostas

# %% [markdown]
# ### Questionamento 1 e tratamento dos dados

# %% [markdown]
# Como estão dispostos os valores agregados de serviços por região do Brasil no ano de 2018?

# %%
df_pib.head()
# Out:
#     ano sigla_uf regiao          pib  impostos_liquidos           va  \
# 0  2002       RO  Norte   7467629886          839731192   6627898698
# 1  2003       RO  Norte   9425010486         1108434936   8316575548
# 2  2004       RO  Norte  11004641436         1288806654   9715834778
# 3  2005       RO  Norte  12511821181         1476144194  11035676990
# 4  2006       RO  Norte  13054713344         1613809974  11440903374
#
#    va_agropecuaria  va_industria  va_servicos  va_adespss
# 0        715526872    1191090432   2484579193  2236702207
# 1       1278658831    1216605061   3376727040  2444584625
# 2       1288515348    1674933817   3986529419  2765856199
# 3       1342222120    1887932121   4603783904  3201738843
# 4       1238006193    2210692147   4320526746  3671678293

# %%
# Criação do df com os dados desejados
va_serv_2018 = df_pib.copy()
va_serv_2018 = va_serv_2018.query('ano == 2018')[['regiao','va_servicos']]

# Agrupamento dos dados por região
va_serv_2018 = va_serv_2018.groupby('regiao')[['va_servicos']].sum().sort_values('va_servicos', ascending=False)
va_serv_2018
# Out:
#                 va_servicos
# regiao
# Sudeste       1933221862566
# Sul            546627330178
# Nordeste       433449662991
# Centro-Oeste   296250896281
# Norte          133394247965

# %% [markdown]
# ### Gerando gráfico de pizza

# %%
# Definição das cores do gráfico
cores = [AZUL2, AZUL5, LARANJA1, VERDE1, CINZA4]

# Geração da área e gráfico
fig, ax = plt.subplots(figsize=(6,6))
plt.suptitle('Disposição do Valor Agregado de Serviços das regiões do Brasil em 2018',
             size=18,
             ha='left',
             x=0.1,
             y=1)

# Personalização do gráfico
ptc, text, _ = ax.pie(data=va_serv_2018, x='va_servicos', labels=va_serv_2018.index,
                      autopct='%.1f%%',
                      pctdistance=0.7,
                      textprops=dict(size=12,
                                     fontweight='bold',
                                     color=BRANCO),
                      colors=cores)

for i, p in enumerate(ptc):
    text[i].set_color(p.get_facecolor())

ax.text(1.5, 0.5,
        'A região $\\bf{Sudeste}$ representa a maior parte do resultado total,\n'
        'com $\\bf{57.8\\%}$. Evidenciando a predominância do estado nesta análise.\n'
        '\nAs regiões $\\bf{Sul}$ e $\\bf{Nordeste}$ também têm números relevantes,\n'
        'juntos, representando $\\bf{29.4\\%}$ do Brasil neste quesito.',
        fontsize=12,
        color=CINZA2,
        va='center')

plt.show()

# %% [markdown]
# ### Questionamento 2 e tratamento dos dados

# %% [markdown]
# Qual a participação da Região Norte nos valores agregados da indústria de todo Brasil nos anos de 2010 e 2020? Podemos notar algum comportamento?

# %%
# Criação dos dfs como desejado
va_ind_norte_2010 = df_pib.copy()
va_ind_norte_2020 = df_pib.copy()

va_ind_norte_2010 = va_ind_norte_2010.query('ano == 2010')[['regiao', 'va_industria']]
va_ind_norte_2020 = va_ind_norte_2020.query('ano == 2020')[['regiao', 'va_industria']]

# Renomeação de todos as regiões, exceto 'Norte', como 'Outros'
va_ind_norte_2010.loc[va_ind_norte_2010['regiao'] == 'Norte', 'regiao'] = 'Região Norte'
va_ind_norte_2010.loc[va_ind_norte_2010['regiao'] != 'Região Norte', 'regiao'] = 'Outras regiões'

va_ind_norte_2020.loc[va_ind_norte_2020['regiao'] == 'Norte', 'regiao'] = 'Região Norte'
va_ind_norte_2020.loc[va_ind_norte_2020['regiao'] != 'Região Norte', 'regiao'] = 'Outras regiões'

# Agrupamento do df por região
va_ind_norte_2010 = va_ind_norte_2010.groupby('regiao').sum()
va_ind_norte_2020 = va_ind_norte_2020.groupby('regiao').sum()

display(va_ind_norte_2010, va_ind_norte_2020)
# Out:
#                 va_industria
# regiao
# Outras regiões  845492561850
# Região Norte     58665438171
#                  va_industria
# regiao
# Outras regiões  1346596521109
# Região Norte     137740478879

# %% [markdown]
# ### Gerando gráfico de rosca

# %%
# Definindo as cores do gráfico
cores = [CINZA5, VERMELHO1]

# Geração da área e gráfico
fig, axs = plt.subplots(1, 2, figsize=(12,6))
plt.suptitle('Valor agregado de indústria da região Norte em relação ao Brasil\nnos anos de 2010 e 2020',
             size=18,
             color=CINZA1,
             ha='left',
             x=0.15,
             y=1)

# Personalizações Gráfico 1
ptc, text, _ = axs[0].pie(data=va_ind_norte_2010,
                          x='va_industria',
                          labels=va_ind_norte_2010.index,
                          autopct='%.1f%%',
                          pctdistance=0.8,
                          startangle=30,
                          wedgeprops=dict(width=0.4),
                          textprops=dict(size=12,
                                         fontweight='bold',
                                         color=BRANCO),
                          colors=cores)

# Ajustando as cores das regiões relativas às fatias
for i, p in enumerate(ptc):
    text[i].set_color(p.get_facecolor())

# Título do gráfico 1
axs[0].annotate('Em 2010', xy=(50,290), size=12, xycoords='axes points',
                bbox=dict(boxstyle='round', fc=BRANCO, ec=CINZA3))

# Personalizações Gráfico 2
ptc, text, _ = axs[1].pie(data=va_ind_norte_2020,
                          x='va_industria',
                          labels=va_ind_norte_2020.index,
                          autopct='%.1f%%',
                          pctdistance=0.8,
                          startangle=30,
                          wedgeprops=dict(width=0.4),
                          textprops=dict(size=12,
                                         fontweight='bold',
                                         color=BRANCO),
                          colors=cores)

# Ajustando as cores das regiões relativas às fatias
for i, p in enumerate(ptc):
    text[i].set_color(p.get_facecolor())

# Título do gráfico 2
axs[1].annotate('Em 2020', xy=(50,290), size=12, xycoords='axes points',
                bbox=dict(boxstyle='round', fc=BRANCO, ec=CINZA3))

# Anotações do gráfico
axs[0].annotate('A Região Norte aumentou\na sua participação no PIB\npor meio da indústria em\naproximadamente 3%',
                xy=(270, 210), xycoords='axes points', xytext=(260, 250), textcoords='axes points',
                bbox=dict(boxstyle="round", fc=BRANCO, ec=CINZA3),
                size=10, arrowprops=dict(arrowstyle="->", fc=CINZA1, connectionstyle="arc,angleA=30,angleB=40,armA=0,armB=30,rad=5"))

axs[1].annotate('\n\n', xy=(250, 200), xycoords='axes points', xytext=(-40, 235),
                textcoords='axes points', size=10, arrowprops=dict(arrowstyle="->", fc=CINZA1, connectionstyle="arc,angleA=-65,angleB=-10,armA=30,armB=-100,rad=5"))
plt.show()

# %% [markdown]
# # Análise 4

# %% [markdown]
# Como está distribuído o PIB do Estado da Bahia em 2020 separado por impostos líquidos e os valores adicionados brutos dos bens e serviços produzidos?

# %% [markdown]
# ### Tratando os dados

# %%
# Criação do df com os dados desejados
bahia = df_pib.query('sigla_uf == "BA" & ano == 2020')[['pib', 'impostos_liquidos', 'va']]

# Renomeando as colunas do df
bahia.rename(columns={'pib':'PIB', 'impostos_liquidos':'Impostos Líquidos', 'va':'Valor Adicionado'}, inplace=True)
bahia
# Out:
#               PIB  Impostos Líquidos  Valor Adicionado
# 303  305320812691        37094030606      268226782074

# %%
# Transformando o df para o formato long com a função 'melt'
bahia = bahia.melt(var_name='Indicadores', value_name='Valores')
bahia
# Out:
#          Indicadores       Valores
# 0                PIB  305320812691
# 1  Impostos Líquidos   37094030606
# 2   Valor Adicionado  268226782074

# %%
# Alterando os impostos para descréscimo, criando uma coluna com os valores em string e outra com as medidas
bahia.loc[bahia['Indicadores'] == 'Impostos Líquidos', 'Valores'] = bahia['Valores'] * -1
bahia['Valores_str'] = (bahia['Valores']/1e9).map('R$ {:,.2f} Bi'.format)
bahia['Medidas'] = ['absolute', 'relative', 'total']

bahia
# Out:
#          Indicadores       Valores   Valores_str   Medidas
# 0                PIB  305320812691  R$ 305.32 Bi  absolute
# 1  Impostos Líquidos  -37094030606  R$ -37.09 Bi  relative
# 2   Valor Adicionado  268226782074  R$ 268.23 Bi     total

# %% [markdown]
# ### Gerando gráfico de cascata

# %%
# Gerando gráfico de cascata
fig = go.Figure(go.Waterfall(name='', orientation='v', measure=bahia['Medidas'],
                             x=bahia['Indicadores'], y=bahia['Valores'],
                             text=bahia['Valores_str'], textposition='outside',
                             connector_line=dict(color=CINZA3),
                             totals_marker=dict(color=AZUL3),
                             decreasing_marker=dict(color=VERMELHO1)))

# Personalização do gráfico
fig.update_layout(width=1000, height=500, font_family='Helvetica',
                  font_size=15, font_color=CINZA2,
                  title_font_color=CINZA1, title_font_size=24,
                  title_text='Distribuição do Produto Interno Bruto (PIB) da Bahia em 2020' +
                             '<br><sup size=1 style="color:#555655">Impostos líquidos e Valores ' +
                             'Adicionados Brutos de bens e serviços (em bilhões de reais)</sup>',
                  title_pad_l=50, plot_bgcolor=BRANCO, yaxis_range=[0,380e9], hovermode='closest')

fig.update_yaxes(showticklabels=False)
fig.update_traces(hovertemplate='<b>%{x}</b> = %{text}')
fig.add_annotation(text='Fonte dos dados: <a href="https://sidra.ibge.gov.br/pesquisa/pib-munic/tabelas">Produto Interno Bruto | IBGE</a>',
                   align='left', xref='paper', yref='paper', x=1, y=-0.2, showarrow=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Análise 5

# %% [markdown]
# Qual a evolução anual do PIB do Estado do Rio de Janeiro entre os anos de 2010 a 2020?

# %% [markdown]
# ### Tratando os dados

# %%
## Criação do df com os dados desejados

# Lista com os anos no período desejado
anos = [x for x in range(2010, 2021)]

rio = df_pib.query('sigla_uf == "RJ" & ano == @anos')[['ano', 'pib']]
rio = rio.reset_index(drop=True)
rio
# Out:
#      ano           pib
# 0   2010  449858101109
# 1   2011  512767904769
# 2   2012  574884973130
# 3   2013  628226069362
# 4   2014  671076844311
# 5   2015  659138951833
# 6   2016  640401206447
# 7   2017  671605668055
# 8   2018  758859046865
# 9   2019  779927917084
# 10  2020  753823710636

# %%
# Gerando coluna com variação do pib e tratando o 1º valor como valor inicial
rio['variacao_pib'] = rio['pib'].diff().fillna(rio['pib']).astype('int64')

# Gerando coluna com as medidas para o gráfico de cascata
rio['Medidas'] = ['absolute'] + ['relative']*10

rio
# Out:
#      ano           pib  variacao_pib   Medidas
# 0   2010  449858101109  449858101109  absolute
# 1   2011  512767904769   62909803660  relative
# 2   2012  574884973130   62117068361  relative
# 3   2013  628226069362   53341096232  relative
# 4   2014  671076844311   42850774949  relative
# 5   2015  659138951833  -11937892478  relative
# 6   2016  640401206447  -18737745386  relative
# 7   2017  671605668055   31204461608  relative
# 8   2018  758859046865   87253378810  relative
# 9   2019  779927917084   21068870219  relative
# 10  2020  753823710636  -26104206448  relative

# %%
# Gerando uma observação com a atualização da última linha com o PIB total de 2020
atualizacao = pd.Series({'ano': 'Total',
                         'pib': rio['pib'].values[-1],
                         'variacao_pib': rio['pib'].values[-1],
                         'Medidas': 'total'}).to_frame().T

# Concatenando o df com a atualização e retirando a coluna pib
rio = pd.concat([rio, atualizacao], axis=0, ignore_index=True)
rio = rio.drop(columns=['pib'])

# Ajustando a formatação do PIB e renomeando colunas
rio['variacao_pib_texto'] = (rio['variacao_pib']/1e9).map('R$ {:,.2f} Bi'.format)
rio.rename(columns={'ano':'Ano', 'variacao_pib': 'Variação do PIB', 'variacao_pib_texto': 'Variação do PIB (em texto)'},
           inplace=True)
rio
# Out:
#       Ano Variação do PIB   Medidas Variação do PIB (em texto)
# 0    2010    449858101109  absolute               R$ 449.86 Bi
# 1    2011     62909803660  relative                R$ 62.91 Bi
# 2    2012     62117068361  relative                R$ 62.12 Bi
# 3    2013     53341096232  relative                R$ 53.34 Bi
# 4    2014     42850774949  relative                R$ 42.85 Bi
# 5    2015    -11937892478  relative               R$ -11.94 Bi
# 6    2016    -18737745386  relative               R$ -18.74 Bi
# 7    2017     31204461608  relative                R$ 31.20 Bi
# 8    2018     87253378810  relative                R$ 87.25 Bi
# 9    2019     21068870219  relative                R$ 21.07 Bi
# 10   2020    -26104206448  relative               R$ -26.10 Bi
# 11  Total    753823710636     total               R$ 753.82 Bi

# %% [markdown]
# ### Gerando gráfico de cascata

# %%
# Gerando gráfico de cascata
fig = go.Figure(go.Waterfall(name='', orientation='v', measure=rio['Medidas'],
                             y=rio['Variação do PIB'], text=rio['Variação do PIB (em texto)'],
                             textposition='outside',
                             connector_line=dict(color=CINZA3),
                             totals_marker=dict(color=AZUL3),
                             decreasing_marker=dict(color=VERMELHO1),
                             increasing_marker=dict(color=VERDE1)))

# Personalização do gráfico
fig.update_layout(width=1300, height=600, font_family='Helvetica',
                  font_size=15, font_color=CINZA2,
                  title_font_color=CINZA1, title_font_size=24,
                  title_text='Variação do Produto Interno Bruto (PIB) do Rio de Janeiro' +
                             '<br><sup size=1 style="color:#555655">De 2010 a 2020 (em bilhões de reais)</sup>',
                  plot_bgcolor=BRANCO, yaxis_range=[0,850e9])

# Retirando os ticks do eixo Y
fig.update_yaxes(showticklabels=False)

# Ajustando o eixo X para receber o Total
fig.update_xaxes(tickmode='array', tickvals=np.arange(0,12), ticktext=rio['Ano'])

# Dados ao passar o mouse
fig.update_traces(hovertemplate='<b>%{x}</b> = %{text}')

# Anotações no gráfico
fig.add_annotation(text='<b>O Rio de Janeiro</b> apresentou recuo no PIB<br>em pelo menos 3 anos no período:<br>2015, 2016 e 2020',
                   align='left', axref='x', ayref='y', x=5, y=600e9, ax=8, ay=450e9,
                   arrowhead=1, arrowside='start', showarrow=True, arrowwidth=2,
                   arrowcolor=CINZA3, bordercolor=CINZA3, borderwidth=1, borderpad=4)
fig.add_annotation(text='',
                   axref='x', ayref='y', x=6, y=600e9, ax=8, ay=530e9,
                   arrowhead=1, arrowside='start', showarrow=True, arrowwidth=2,
                   arrowcolor=CINZA3)
fig.add_annotation(text='',
                   axref='x', ayref='y', x=10, y=710e9, ax=8.5, ay=530e9,
                   arrowhead=1, arrowside='start', showarrow=True, arrowwidth=2,
                   arrowcolor=CINZA3)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Análise proposta

# %% [markdown]
# A representação acima para o estado de Minas Gerais

# %%
# Criando DF com os dados desejados
anos = [x for x in range(2010, 2021)]
minas = df_pib.query('sigla_uf == "MG" & ano == @anos')[['ano', 'pib']]

# Criação de colunas com a variação do 'pib' e tratando os NaNs
minas['variacao_pib'] = minas['pib'].diff().fillna(minas['pib']).astype('int64')
minas['Medidas'] = ['absolute'] + ['relative']*10
minas.reset_index(inplace=True, drop=True)

minas
# Out:
#      ano           pib  variacao_pib   Medidas
# 0   2010  351123417732  351123417732  absolute
# 1   2011  400124687035   49001269303  relative
# 2   2012  442282829874   42158142839  relative
# 3   2013  488004903011   45722073137  relative
# 4   2014  516633984096   28629081085  relative
# 5   2015  519331213138    2697229042  relative
# 6   2016  544810468390   25479255252  relative
# 7   2017  576375544684   31565076294  relative
# 8   2018  614875819797   38500275113  relative
# 9   2019  651872684368   36996864571  relative
# 10  2020  682786116407   30913432039  relative

# %%
# Gerando uma observação com a atualização da última linha com o PIB total de 2020
atualizacao = pd.Series({'ano': 'Total',
                         'pib': minas['pib'].values[-1],
                         'variacao_pib': minas['pib'].values[-1],
                         'Medidas': 'total'}).to_frame().T

# Concatenando o df com a atualização e retirando a coluna pib
minas = pd.concat([minas, atualizacao], axis=0, ignore_index=True)
minas = minas.drop(['pib'], axis=1)

# Ajustando formatação e renomeando colunas
minas['variacao_pib_texto'] = (minas['variacao_pib']/1e9).map('R$ {:,.2f} Bi'.format)
minas.rename(columns={'ano':'Ano', 'variacao_pib':'Variação do PIB', 'variacao_pib_texto': 'Variação do PIB (em texto)'},
             inplace=True)

minas
# Out:
#       Ano Variação do PIB   Medidas Variação do PIB (em texto)
# 0    2010    351123417732  absolute               R$ 351.12 Bi
# 1    2011     49001269303  relative                R$ 49.00 Bi
# 2    2012     42158142839  relative                R$ 42.16 Bi
# 3    2013     45722073137  relative                R$ 45.72 Bi
# 4    2014     28629081085  relative                R$ 28.63 Bi
# 5    2015      2697229042  relative                 R$ 2.70 Bi
# 6    2016     25479255252  relative                R$ 25.48 Bi
# 7    2017     31565076294  relative                R$ 31.57 Bi
# 8    2018     38500275113  relative                R$ 38.50 Bi
# 9    2019     36996864571  relative                R$ 37.00 Bi
# 10   2020     30913432039  relative                R$ 30.91 Bi
# 11  Total    682786116407     total               R$ 682.79 Bi

# %%
# Gerando gráfico de cascata
fig = go.Figure(go.Waterfall(name='', orientation='v', measure=minas['Medidas'],
                             y=minas['Variação do PIB'], text=minas['Variação do PIB (em texto)'],
                             textposition='outside', connector_line=dict(color=CINZA3),
                             totals_marker=dict(color=AZUL3),
                             increasing_marker=dict(color=VERDE1)))

# Personalizações do gráfico
fig.update_layout(width=1600, height=600, font_family='Helvetica', font_size=15,
                  font_color=CINZA2, title_font_color=CINZA1, title_font_size=24,
                  title_text='Variação do Produto Interno Bruto (PIB) de Minas Gerais' +
                             '<br><sup size=1 style="color:#555655">De 2010 a 2020 (em bilhões de reais)</sup>',
                  plot_bgcolor=BRANCO, yaxis_range=(0,780e9))

fig.update_yaxes(showticklabels=False)
fig.update_xaxes(tickmode='array', tickvals=np.arange(0,12), ticktext=rio['Ano'])
fig.update_traces(hovertemplate='%{x} = %{text}')

# Anotações no gráfico
fig.add_annotation(text='<b>Minas Gerais</b> apresentou crescimento no PIB<br>em em todos os anos do período analisado.',
                   align='left', axref='x', ayref='y', x=8, y=400e9, ax=8, ay=450e9,
                   arrowhead=1, arrowside='start', showarrow=False,
                   bordercolor=CINZA3, borderwidth=1, borderpad=4)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Análises propostas

# %% [markdown]
# ### Questionamento 1 e tratamento dos dados

# %% [markdown]
# Como está composto o PIB do Estado de São Paulo em 2020 partindo do valor agregado bruto dos bens e serviços produzidos e os impostos líquidos?

# %%
# Criando df com os dados desejados
sp_2020 = df_pib.query('sigla_uf == "SP" & ano == 2020')[['pib', 'impostos_liquidos', 'va']]

# Renomeando as colunas
sp_2020.rename(columns={'pib':'PIB', 'impostos_liquidos':'Impostos Líquidos', 'va':'Valor Adicionado Bruto'},
               inplace=True)

sp_2020 = sp_2020[['Valor Adicionado Bruto', 'Impostos Líquidos', 'PIB']]

sp_2020
# Out:
#      Valor Adicionado Bruto  Impostos Líquidos            PIB
# 379           2014850308310       362788671543  2377638979835

# %%
# Transformando o df para o formato long com a função melt
sp_2020 = sp_2020.melt(var_name='Indicadores', value_name='Valores')
sp_2020
# Out:
#               Indicadores        Valores
# 0  Valor Adicionado Bruto  2014850308310
# 1       Impostos Líquidos   362788671543
# 2                     PIB  2377638979835

# %%
# Criando uma coluna com os valores em string e outra com as medidas
sp_2020['Valores_str'] = (sp_2020['Valores']/1e12).map('R$ {:,.2f} Tri'.format)
sp_2020['Medidas'] = ['absolute', 'relative', 'total']

sp_2020
# Out:
#               Indicadores        Valores  Valores_str   Medidas
# 0  Valor Adicionado Bruto  2014850308310  R$ 2.01 Tri  absolute
# 1       Impostos Líquidos   362788671543  R$ 0.36 Tri  relative
# 2                     PIB  2377638979835  R$ 2.38 Tri     total

# %% [markdown]
# ### Gerando gráfico de cascata

# %%
# Gerando gráfico de cascata
fig = go.Figure(go.Waterfall(name='', orientation='v', measure=sp_2020['Medidas'],
                             x=sp_2020['Indicadores'], y=sp_2020['Valores'],
                             text=sp_2020['Valores_str'], textposition='outside',
                             connector_line=dict(color=CINZA3),
                             totals_marker=dict(color=AZUL4),
                             increasing_marker=dict(color=CINZA2)))

# Personalização do gráfico
fig.update_layout(width=1000, height=500, font_family='Helvetica',
                  font_size=15, font_color=CINZA2,
                  title_font_color=CINZA1, title_font_size=24,
                  title_text='Composição do Produto Interno Bruto (PIB) de São Paulo em 2020' +
                             '<br><sup size=1 style="color:#555655">Impostos líquidos e Valores ' +
                             'Adicionados Brutos de bens e serviços (em trilhões de reais)</sup>',
                  title_pad_l=50, plot_bgcolor=BRANCO, yaxis_range=[0,3e12], hovermode='closest')

fig.update_yaxes(showticklabels=False)
fig.update_traces(hovertemplate='<b>%{x}</b> = %{text}')
fig.add_annotation(text='Fonte dos dados: <a href="https://sidra.ibge.gov.br/pesquisa/pib-munic/tabelas">Produto Interno Bruto | IBGE</a>',
                   align='left', xref='paper', yref='paper', x=1, y=-0.2, showarrow=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Questionamento 2 e tratamento dos dados

# %% [markdown]
# Qual a evolução anual do valor agregado de serviços na Região Nordeste entre os anos de 2016 a 2020?

# %%
# Criando df com os dados desejados
anos = [x for x in range(2016, 2021)]
nordeste_va = df_pib.query('regiao == "Nordeste" & ano == @anos')[['ano', 'va_servicos']]

# Agrupando os dados por ano
nordeste_va = nordeste_va.groupby('ano').sum()

nordeste_va
# Out:
#        va_servicos
# ano
# 2016  391149062027
# 2017  413890511671
# 2018  433449662991
# 2019  450661680677
# 2020  436102799877

# %%
# Criando coluna com a variação do 'va_servicos' durante os anos e tratando os NaNs
nordeste_va['variacao_va_serv'] = nordeste_va['va_servicos'].diff().fillna(nordeste_va['va_servicos']).astype('int64')

# Criando coluna com as medidas
nordeste_va['Medidas'] = ['absolute'] + ['relative'] * 4

nordeste_va = nordeste_va.reset_index()
nordeste_va
# Out:
#     ano   va_servicos  variacao_va_serv   Medidas
# 0  2016  391149062027      391149062027  absolute
# 1  2017  413890511671       22741449644  relative
# 2  2018  433449662991       19559151320  relative
# 3  2019  450661680677       17212017686  relative
# 4  2020  436102799877      -14558880800  relative

# %%
# Gerando uma observação com a atualização da última linha
atualizacao = pd.Series({'ano':'Total',
                         'va_servicos':nordeste_va['va_servicos'].values[-1],
                         'variacao_va_serv':nordeste_va['va_servicos'].values[-1],
                         'Medidas':'total'}).to_frame().T

# Concatenação do df com a atualização
nordeste_va = pd.concat([nordeste_va, atualizacao], axis=0, ignore_index=True)

# Formatação da coluna criada e remoção da coluna va_servicos
nordeste_va['variacao_va_serv_str'] = (nordeste_va['variacao_va_serv']/1e9).map('R$ {:,.2f} Bi'.format)
nordeste_va = nordeste_va.drop(['va_servicos'], axis=1)

nordeste_va
# Out:
#      ano variacao_va_serv   Medidas variacao_va_serv_str
# 0   2016     391149062027  absolute         R$ 391.15 Bi
# 1   2017      22741449644  relative          R$ 22.74 Bi
# 2   2018      19559151320  relative          R$ 19.56 Bi
# 3   2019      17212017686  relative          R$ 17.21 Bi
# 4   2020     -14558880800  relative         R$ -14.56 Bi
# 5  Total     436102799877     total         R$ 436.10 Bi

# %%
# Renomeando colunas
nordeste_va.rename(columns={'ano':'Ano',
                            'variacao_va_serv':'Variação VA Serviços',
                            'variacao_va_serv_str': 'Variação VA (em texto)'},
                   inplace=True)
nordeste_va
# Out:
#      Ano Variação VA Serviços   Medidas Variação VA (em texto)
# 0   2016         391149062027  absolute           R$ 391.15 Bi
# 1   2017          22741449644  relative            R$ 22.74 Bi
# 2   2018          19559151320  relative            R$ 19.56 Bi
# 3   2019          17212017686  relative            R$ 17.21 Bi
# 4   2020         -14558880800  relative           R$ -14.56 Bi
# 5  Total         436102799877     total           R$ 436.10 Bi

# %% [markdown]
# ### Gerando gráfico de cascata

# %%
# Gerando gráfico de cascata
fig = go.Figure(go.Waterfall(name='', orientation='v', measure=nordeste_va['Medidas'],
                             y=nordeste_va['Variação VA Serviços'], text=nordeste_va['Variação VA (em texto)'],
                             textposition='outside',
                             connector_line=dict(color=CINZA3),
                             totals_marker=dict(color=AZUL3),
                             decreasing_marker=dict(color=VERMELHO1),
                             increasing_marker=dict(color=VERDE1)))

# Personalização do gráfico
fig.update_layout(width=1300, height=600, font_family='Helvetica',
                  font_size=15, font_color=CINZA2,
                  title_font_color=CINZA1, title_font_size=24,
                  title_text='Variação do Valor Adicionado de serviços da região Nordeste' +
                             '<br><sup size=1 style="color:#555655">De 2016 a 2020 (em bilhões de reais)</sup>',
                  plot_bgcolor=BRANCO, yaxis_range=[0,480e9])

# Retirando os ticks do eixo Y
fig.update_yaxes(showticklabels=False)

# Ajustando o eixo X para receber o Total
fig.update_xaxes(tickmode='array', tickvals=np.arange(0,6), ticktext=nordeste_va['Ano'])

# Dados ao passar o mouse
fig.update_traces(hovertemplate='<b>%{x}</b> = %{text}')

# Anotações no gráfico
fig.add_annotation(text='A região <b>Nordeste</b> apresentou recuo no VA de serviços<br>apenas no ano de <b>2020</b> no período analisado.',
                   align='left', axref='x', ayref='y', x=4, y=410e9, ax=3, ay=250e9,
                   arrowhead=1, arrowside='start', showarrow=True, arrowwidth=2,
                   arrowcolor=CINZA3, bordercolor=CINZA3, borderwidth=1, borderpad=4)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Análise 6

# %% [markdown]
# Como está distribuído o PIB nos 3 últimos quinquênios (lustro) dos dados (2010, 2015, 2020) na Região Sul do Brasil divididos pelos Estados (Paraná, Santa Catarina e Rio Grande do Sul)?

# %% [markdown]
# ### Tratando os dados

# %%
# Selecionando os dados de acordo com o desejado
anos = [x for x in range(2010,2021,5)]

pib_sul = df_pib.query('regiao == "Sul" & ano == @anos')[['ano', 'sigla_uf', 'pib']]

pib_sul['pib'] = round(pib_sul['pib']/1e9, 2)
pib_sul = pib_sul.reset_index(drop=True)

pib_sul
# Out:
#     ano sigla_uf     pib
# 0  2010       PR  225.21
# 1  2015       PR  376.96
# 2  2020       PR  487.93
# 3  2010       SC  153.73
# 4  2015       SC  249.08
# 5  2020       SC  349.28
# 6  2010       RS  241.25
# 7  2015       RS  381.99
# 8  2020       RS  470.94

# %%
# Criação de tabela cruzada (crosstab) com os valores do pib de cada ano por região
pib_sul_cross = pd.crosstab(index=pib_sul.ano,
                            columns=pib_sul.sigla_uf,
                            values=pib_sul.pib,
                            aggfunc='sum',
                            normalize='index')

pib_sul_cross = pib_sul_cross.reset_index()

pib_sul_cross
# Out:
# sigla_uf   ano        PR        RS        SC
# 0         2010  0.363131  0.388994  0.247876
# 1         2015  0.373957  0.378947  0.247096
# 2         2020  0.372992  0.360005  0.267003

# %% [markdown]
# ### Gerando gráfico de colunas

# %%
# Gerando área e tema do gráfico
fig, axs = plt.subplots(1, 2, figsize=(16,6))
sns.set_theme(style='white')

# Definindo as cores do gráfico
cores = [AZUL6, VERDE3, VERMELHO2]

fig.suptitle('Distribuição do PIB na região Sul do Brasil por quinquênio (2010 - 2020)',
             fontsize=18, color=CINZA1, ha='right', x=0.66, y=1.05)

# Gráfico 1 de colunas agrupadas
sns.barplot(data=pib_sul, x='ano', y='pib',
            hue='sigla_uf',
            hue_order=['PR', 'RS', 'SC'],
            ax = axs[0],
            palette=cores,
            legend=False)

axs[0].set_title('Em bilhões de reais\n', color=CINZA3, loc='left')
axs[0].set_xlabel('')
axs[0].set_ylabel('')
axs[0].xaxis.set_tick_params(labelsize=12, labelcolor=CINZA2)
axs[0].yaxis.set_tick_params(labelsize=12, labelcolor=CINZA2)
axs[0].set_frame_on(False)
axs[0].yaxis.grid(linestyle='--', linewidth=1)


# Gráfico 2 de colunas empilhadas (100%)
pib_sul_cross.plot(x='ano', kind='bar', stacked=True, color=cores, ax = axs[1])

axs[1].set_title('Em porcentagem\n', color=CINZA3, loc='left')
axs[1].set_xlabel('')
axs[1].set_ylabel('')
axs[1].set_yticklabels([])
axs[1].xaxis.set_tick_params(labelsize=12, labelcolor=CINZA2, labelrotation=0)
axs[1].set_frame_on(False)

# Personalizando legenda entre os dois gráficos
axs[1].legend(bbox_to_anchor=(-0.005,1), title='Estado', title_fontsize=12, fontsize=12)

# Adicionando valores dentro da coluna
for container in axs[1].containers:
    labels=[f'{valor.get_height()*100:.0f}%' for valor in container]
    axs[1].bar_label(container, label_type='center', labels=labels, size=11,
                     color=CINZA3, fontweight='bold')

plt.show()

# %% [markdown]
# # Análise 7

# %% [markdown]
# Como estão distribuídos, em porcentagem, os valores adicionados de bens e serviços descritos na base de dados em relação a cada região no ano de 2020?

# %% [markdown]
# ### Tratando os dados

# %%
# Selecionando os dados desejados
df_va_separado = df_pib.query('ano == 2020')[['regiao', 'va_servicos', 'va_industria', 'va_adespss', 'va_agropecuaria']]
df_va_separado = df_va_separado.reset_index(drop=True)
df_va_separado.head()
# Out:
#   regiao  va_servicos  va_industria   va_adespss  va_agropecuaria
# 0  Norte  19060688172    8285675423  12000339417       6891411669
# 1  Norte   6590543336    1191345379   6031050521        983531817
# 2  Norte  34795836262   35839810630  20210620577       5114449144
# 3  Norte   5278754961    1706511471   6538065265       1000907462
# 4  Norte  56395092425   84173852308  37614037902      19730656823

# %%
# Agrupando os dados por região
df_va_separado = df_va_separado.groupby('regiao').sum()

# Normalizando os dados de cada região
df_va_separado = df_va_separado.div(df_va_separado.sum(axis=1), axis=0)
df_va_separado = df_va_separado.sort_values('va_servicos')

df_va_separado
# Out:
#               va_servicos  va_industria  va_adespss  va_agropecuaria
# regiao
# Norte            0.338521      0.323217    0.239485         0.098777
# Centro-Oeste     0.435471      0.153645    0.266185         0.144699
# Nordeste         0.459790      0.191011    0.260121         0.089078
# Sul              0.508060      0.252751    0.139648         0.099541
# Sudeste          0.610871      0.228032    0.133536         0.027561

# %% [markdown]
# ### Gerando gráfico de barras empilhadas

# %%
# Gerando função para criar o gráfico de barrar
def grafico_va():
    # Área do gráfico
    fig, ax = plt.subplots(figsize=(10,7))

    # Definindo cores do gráfico
    cores = [AZUL3, LARANJA1, CINZA5, VERDE3]

    # Gerando gráfico de barras empilhadas (100%)
    df_va_separado.plot(kind='barh', stacked=True, color=cores, ax=ax)

    # Personalização do gráfico
    plt.suptitle('Valores adicionados de bens e serviços do PIB brasileiro em 2020',
                 size=18,
                 color=CINZA1,
                 ha='right',
                 x=0.8,
                 y=1.01)
    plt.title('Em distribuição dos setores por região (%)\n',
              fontsize=14,
              color=CINZA3,
              pad=15,
              ha='right',
              x=0.35)
    ax.legend(bbox_to_anchor=(1,1),
              bbox_transform=ax.transAxes,
              fontsize=10,
              loc='upper left')
    ax.set_ylabel('')
    ax.set_xticklabels([])
    ax.yaxis.set_tick_params(labelsize=14,
                             labelcolor=CINZA2)
    ax.set_frame_on(False)

    # Valores nas barras
    for container in ax.containers:
        labels=[f'{valor.get_width()*100:.0f}%' for valor in container]
        ax.bar_label(container,
                     label_type='center',
                     labels=labels,
                     size=10,
                     color=CINZA2,
                     fontweight='bold')

    return ax, cores

ax, cores = grafico_va()

# %%
# Função para escrita de texto utilizando diferentes cores
# Adapado de https://github.com/empathy87/storytelling-with-data
def texto_colorido(x, y, texto, cores, esp=20, ax=None, **kw):
    cores = list(reversed(cores))
    t = ax.transData
    canvas = ax.figure.canvas

    for i, linha in enumerate(reversed(texto.split('\n'))):
        frases = linha.split('||')
        for s, cor in zip(frases, cores[i]):
            texto = ax.text(x, y, s, color=cor, transform=t, **kw)
            texto.draw(canvas.get_renderer())
            ex = texto.get_window_extent()
            t = transforms.offset_copy(texto._transform, x=ex.width,
                                       units='dots')

        t = transforms.offset_copy(ax.transData, x=0, y=(i + 1) * esp, units='dots')

# %% [markdown]
# ### Gráfico de barras empilhadas final

# %%
# Configurando o gráfico com parâmetros
ax, cores = grafico_va()

# Legenda das barras
ax.legend().remove()
texto_colorido(0, 4.4, '$\\bf{Serviços}$ || | || $\\bf{Indústria}$ || | || $\\bf{ADESPSS}$ || | || $\\bf{Agropecuária}$',
               cores = [[cores[0], CINZA3, cores[1], CINZA3, cores[2], CINZA3, cores[3]]], ax=ax, fontsize=12)

# Anotação no gráfico
texto_colorido(
    1.05, 2,                                                             # coordenadas
    'O setor de ||$\\bf{serviços}$|| corresponde a maior fatia\n'        # texto
    'do PIB em todas as regiões. Na Região ||$\\bf{Sudeste}$||,\n'
    'ele representa ||$\\bf{mais\\;de\\;60\\%}$|| do PIB frente a outros setores.\n'
    '\n'
    'O setor de ||$\\bf{ADESPSS\\;(Administração,\\;Defesa,\\;Educação,}$\n'
    '$\\bf{Saúde\\;Pública\\;e\\;Seguridade\\;Social)}$|| é o ||$\\bf{2º\\;mais\\;relevante}$||\n'
    'no PIB da Região ||$\\bf{Nordeste}$||.\n'
    '\n'
    'O setor com menor participação é o da ||$\\bf{agropecuária}$||.\n'
    'Na Região ||$\\bf{Centro-Oeste}$|| ele praticamente empata com\n'
    'o setor da ||$\\bf{indústria}$|| em peso na região.',
    [[CINZA3, AZUL3, CINZA3],         # linha 1                          # cores
     [CINZA3, CINZA1, CINZA3],        # linha 2
     [CINZA3, CINZA1, CINZA3],        # linha 3
     [CINZA3],                        # linha 4
     [CINZA3, CINZA5],                # linha 5
     [CINZA5, CINZA3, CINZA1],        # linha 6
     [CINZA3, CINZA1, CINZA3],        # linha 7
     [CINZA3],                        # linha 8
     [CINZA3, VERDE3, CINZA3],        # linha 9
     [CINZA3, CINZA1, CINZA3],        # linha 10
     [CINZA3, LARANJA1, CINZA3]       # linha 11
    ],
    esp=22,         # espaçamento
    ax=ax,          # figura onde desenhar o texto
    fontsize=12)

fig.show()

# %% [markdown]
# # Análises propostas

# %% [markdown]
# ### Questionamento 1 e tratamento dos dados

# %% [markdown]
# Como está composto, em valores absolutos, o PIB por região dos 4 últimos anos do conjunto de dados (2017 a 2020)?

# %%
# Definindo df com os dados desejados
anos = [x for x in range(2017,2021)]
pib_regiao = df_pib.query('ano == @anos')[['ano', 'regiao', 'pib']]
pib_regiao['pib'] = round(pib_regiao['pib']/1e12, 2)
pib_regiao = pib_regiao.reset_index(drop=True)
pib_regiao.head()
# Out:
#     ano regiao   pib
# 0  2017  Norte  0.04
# 1  2018  Norte  0.04
# 2  2019  Norte  0.05
# 3  2020  Norte  0.05
# 4  2017  Norte  0.01

# %%
# Agrupando os dados por região/ano
pib_regiao = pd.crosstab(index=pib_regiao.ano,
                         columns=pib_regiao.regiao,
                         values=pib_regiao.pib,
                         aggfunc='sum')
pib_regiao
# Out:
# regiao  Centro-Oeste  Nordeste  Norte  Sudeste   Sul
# ano
# 2017            0.66      0.95   0.36     3.48  1.12
# 2018            0.70      1.01   0.39     3.72  1.20
# 2019            0.73      1.04   0.43     3.92  1.27
# 2020            0.79      1.09   0.49     3.95  1.31

# %%
# Definido ordem das regiões
pib_regiao = pib_regiao[['Sudeste', 'Sul', 'Nordeste', 'Centro-Oeste', 'Norte']]

# %% [markdown]
# ### Gerando o gráfico de colunas empilhadas

# %%
# Definindo as cores do gráfico
cores = [AZUL4, VERMELHO2, AZUL5, VERDE3, CINZA5]

# Gerando área e definindo tema do gráfico
fig, ax = plt.subplots(figsize=(12,6))
sns.set_theme(style='white')

# Gráfico de colunas empilhadas
pib_regiao.plot(kind='bar', stacked=True, color=cores, ax=ax)

# Personalização do gráfico
plt.suptitle('Composição do PIB brasileiro por região entre os anos de 2017 a 2020',
              size=18,
              color=CINZA1,
              ha='right',
              x=0.91,
              y=1.01)
plt.title('Em trilhões de reais\n',
          fontsize=14,
          color=CINZA3,
          pad=15,
          ha='left',
          x=0.07,
          y=0.97)
ax.legend(bbox_to_anchor=(1,1),
          bbox_transform=ax.transAxes,
          fontsize=10,
          reverse=True,
          loc='upper left',
          title='Região')
ax.set_ylabel('')
ax.set_xlabel('')
ax.set_yticklabels([])
ax.xaxis.set_tick_params(labelsize=14,
                         labelcolor=CINZA2,
                         labelrotation=0)
ax.set_frame_on(False)

# Valores nas colunas
for container in ax.containers:
    labels=[f'{valor.get_height():.2f} Tri' for valor in container]
    ax.bar_label(container,
                label_type='center',
                labels=labels,
                size=10,
                color=CINZA2,
                fontweight='bold')
plt.show()

# %% [markdown]
# ### Questionamento 2 e tratando os dados

# %% [markdown]
# Como está composto os valores agregados brutos dos bens e serviços (em valor absoluto) em relação aos Estados da região Centro-Oeste no ano de 2020?

# %%
# Definindo colunas do df
colunas = ['sigla_uf', 'va_agropecuaria', 'va_industria', 'va_servicos', 'va_adespss']

# Selecionando os dados desejados
va_centro_2020 = df_pib.query('regiao == "Centro-Oeste" & ano == 2020')[colunas]
va_centro_2020 = va_centro_2020.reset_index(drop=True)

# Arredondando valores em bilhões
va_centro_2020[colunas[1:]] = round(va_centro_2020[colunas[1:]]/1e9, 2)

va_centro_2020
# Out:
#   sigla_uf  va_agropecuaria  va_industria  va_servicos  va_adespss
# 0       MS            26.05         23.31        40.46       20.08
# 1       MT            46.00         27.66        62.25       23.69
# 2       GO            29.02         47.12        89.80       33.89
# 3       DF             1.62         10.94       116.55      111.27

# %%
# Agrupando e ordernando o df
va_centro_2020 = va_centro_2020.groupby('sigla_uf').sum()
va_centro_2020 = va_centro_2020.sort_values('va_servicos')
va_centro_2020 = va_centro_2020[['va_servicos', 'va_industria', 'va_adespss', 'va_agropecuaria']]

va_centro_2020
# Out:
#           va_servicos  va_industria  va_adespss  va_agropecuaria
# sigla_uf
# MS              40.46         23.31       20.08            26.05
# MT              62.25         27.66       23.69            46.00
# GO              89.80         47.12       33.89            29.02
# DF             116.55         10.94      111.27             1.62

# %% [markdown]
# ### Gerando o gráfico de barras empilhadas

# %%
# Gerando área do gráfico
fig, ax = plt.subplots(figsize=(12,7))

# Definindo cores do gráfico
cores = [AZUL3, LARANJA1, CINZA5, VERDE3]

# Gerando gráfico de barras empilhadas (valores absolutos)
va_centro_2020.plot(kind='barh', stacked=True, color=cores, ax=ax)

# Personalização do gráfico
plt.suptitle('Valores adicionados de bens e serviços da região Centro-Oeste do Brasil em 2020',
             size=18,
             color=CINZA1,
             ha='right',
             x=0.98,
             y=1)
plt.title('Em bilhões de reais\n',
          fontsize=14,
          color=CINZA3,
          pad=15,
          ha='right',
          x=0.209,
          y=0.99)

ax.legend().remove()
ax.set_xlabel('')
ax.set_ylabel('')
ax.set_xticklabels([])
ax.yaxis.set_tick_params(labelsize=12, labelcolor=CINZA3)
ax.set_frame_on(False)

# Valores nas barras
for container in ax.containers:
    labels=[f'{valor.get_width():.0f} Bi' for valor in container]
    ax.bar_label(container, label_type='center', labels=labels, size=10, color=CINZA1, fontweight='bold')

# Personalização da legenda
texto_colorido(0, 3.35, '$\\bf{Serviços}$ || | || $\\bf{Indústria}$ || | || $\\bf{ADESPSS}$ || | || $\\bf{Agropecuária}$',
               cores = [[cores[0], CINZA3, cores[1], CINZA3, cores[2], CINZA3, cores[3]]], ax=ax, fontsize=12)

# Anotação no gráfico
texto_colorido(255, 1.8,
               'Em 2020, o ||$\\bf{Distrito\\;Federal}$|| liderou em dois setores no Centro-Oeste:\n'
               '$\\bf{Serviços}$|| e ||$\\bf{ADESPSS\\;(Administração,\\;Defesa,\\;Educação,}$\n'
               '$\\bf{Saúde\\;Pública\\;e\\;Seguridade\\;Social)}$.\n'
               '\n'
               '$\\bf{Goiás}$|| foi o estado com maior participação em ||$\\bf{Indústria}$|| e ||$\\bf{Mato\\;Grosso}$\n'
               'em ||$\\bf{Agropecuária}$||.\n'
               '\n'
               'Já ||$\\bf{Mato\\;Grosso\\;do\\;Sul}$||, em números gerais, ultrapassa apenas o\n'
               '$\\bf{Distrito\\;Federal}$|| em dois setores: ||$\\bf{Indústria}$|| e ||$\\bf{Agropecuária}$ ||.',
               [[CINZA3, CINZA1, CINZA3],
                [AZUL3, CINZA3, CINZA5],
                [CINZA5],
                [CINZA3],
                [CINZA1, CINZA3, LARANJA1, CINZA3, CINZA1],
                [CINZA3, VERDE3, CINZA3],
                [CINZA3],
                [CINZA3, CINZA1, CINZA3],
                [CINZA1, CINZA3, LARANJA1, CINZA3, VERDE3, CINZA3],],
               esp=22,
               ax=ax,
               fontsize=12)

plt.show()

# %% [markdown]
# # Análise 8

# %% [markdown]
# Na agropecuária, como estão distribuídos seus valores adicionados por região dentro do período da base dos dados (2002 - 2020)?

# %% [markdown]
# ### Tratando os dados

# %%
# Selecionando os dados desejados
df_agro = df_pib.copy()
df_agro = df_agro[['regiao', 'ano', 'va_agropecuaria']]

# Agrupando os dados por região
df_agro = pd.crosstab(index=df_agro.ano,
                      columns=df_agro.regiao,
                      values=df_agro.va_agropecuaria,
                      aggfunc='sum')
df_agro = round(df_agro/1e9, 2)
df_agro.head()
# Out:
# regiao  Centro-Oeste  Nordeste  Norte  Sudeste    Sul
# ano
# 2002           12.98     17.04   6.40    22.57  22.53
# 2003           18.70     20.98   8.14    25.71  32.42
# 2004           20.98     22.44   8.18    28.27  31.05
# 2005           17.04     22.03   8.53    28.99  24.37
# 2006           12.15     23.42   8.91    34.44  26.37

# %% [markdown]
# ### Gerando gráfico de área

# %%
# Gerando área do gráfico
fig, ax = plt.subplots(figsize=(14,7))

# Definindo as cores do gráfico
cores = [VERDE3, VERMELHO2, AZUL3, LARANJA1, CINZA4]

# Gerando gráfico de área
df_agro.plot(kind='area',
             stacked=True,
             color=cores,
             ax=ax,
             xticks=range(2002, 2021, 2))

# Personalização do gráfico
ax.set_title('PIB relativo à agropecuária nas regiões do Brasil',
             fontsize=18,
             color=CINZA1,
             loc='left')
ax.text(0.29, 0.98, 'De 2002 a 2020 (em bilhões de reais)',
         transform=ax.transAxes,
         color=CINZA3,
         fontsize=12,
         ha='right',
         va='center')
ax.set_ylabel('')
ax.set_xlabel('')
ax.xaxis.set_tick_params(labelsize=14,
                         labelcolor=CINZA2)
ax.legend().remove()
ax.set_frame_on(False)

# Anotando os nomes da regiões
reg = list(reversed(df_agro.columns))
cor = list(reversed(cores))
for i in range(len(reg)):
    ax.text(0.97, (0.67 - i/7), f'{reg[i]}',
            fontsize=14,
            color=cor[i],
            transform=ax.transAxes)

# Ajustes no eixo X e Y
plt.ylim(0, 500)
ax.get_yaxis().set_visible(False)
ax.tick_params(axis='both', which='both', length=0)

# Destacando os valores
agregado_ano = list(df_agro.sum(axis=1).round(2))
for i in range(0, len(df_agro.index), 4):
    ax.text(x=df_agro.index[i], y=agregado_ano[i] + 20, s=f'{agregado_ano[i]} Bi',
            color=CINZA3,
            weight='bold',
            fontsize=10,
            ha='center')
ax.text(x=df_agro.index[-1], y=agregado_ano[-1] + 20, s=f'{agregado_ano[-1]} Bi',
        color=CINZA3,
        weight='bold',
        fontsize=10,
        ha='center')

plt.show()

# %% [markdown]
# ### Tratando os dados (inclinação)

# %%
# Selecionando os dados desejados
df_agro_slope = df_pib.query('ano == [2002, 2020]')[['regiao', 'ano', 'va_agropecuaria']]

# Agrupando os dados por região
df_agro_slope = pd.crosstab(index=df_agro_slope.ano,
                            columns=df_agro_slope.regiao,
                            values=df_agro_slope.va_agropecuaria,
                            aggfunc='sum',
                            normalize='index')
df_agro_slope = round(df_agro_slope * 100, 1)

df_agro_slope.head()
# Out:
# regiao  Centro-Oeste  Nordeste  Norte  Sudeste   Sul
# ano
# 2002            15.9      20.9    7.9     27.7  27.6
# 2020            23.6      19.4    9.7     21.5  25.8

# %% [markdown]
# ### Gerando gráfico de inclinação

# %%
# Gerando função para criar gráfico de inclinação
def grafico_slope_agro():
    # Área do gráfico
    fig, ax1 = plt.subplots(figsize=(7,7))

    # Definindo as cores do gráfico
    cores = [VERDE3, VERMELHO2, AZUL3, LARANJA1, CINZA4]

    # Criando outro eixo Y que compartilha o mesmo eixo X
    ax2 = ax1.twinx()
    ax1.set_ylim([0,35])
    ax2.set_ylim([0,35])

    # Gerando gráfico de inclinação
    for i in range(5):
        # Adicionando o ponto inicial e final
        ax1.scatter(x=df_agro_slope.index,
                    y=df_agro_slope.iloc[:,i],
                    color = cores[i],
                    s=50)

        # Adicionando a inclinação
        ax1.plot(df_agro_slope.index,
                 df_agro_slope.iloc[:,i],
                 color = cores[i],
                 lw=3)

        # Adicionando as regiões no label
        ax1.text(x=2024,
                 y=df_agro_slope.iloc[-1,i],
                 s=df_agro_slope.columns[i],
                 fontsize=15,
                 fontweight='bold',
                 linespacing=1.5,
                 color=cores[i],
                 va='center')

    # Personalização do gráfico
    ax1.set_title('PIB relativo à agropecuária nas regiões do Brasil',
                  fontsize=18,
                  color=CINZA1,
                  loc='left',
                  pad=40)
    ax1.text(0.01, 1, 'Comparação entre os anos de 2002 e 2020 (%)',
             transform=ax.transAxes,
             color=CINZA3,
             fontsize=12,
             ha='left',
             va='center')

    return ax1, ax2, cores

ax1, ax2, cores = grafico_slope_agro()

# %% [markdown]
# ### Gráfico de inclinação final

# %%
# Personalização do gráfico de inclinação para melhor visualização
ax1, ax2, cores = grafico_slope_agro()

# Retirando os ticks do eixo Y de ambos os lados e as bordas
ax1.tick_params(left=False)
ax1.spines[['top', 'left', 'right']].set_visible(False)
ax2.tick_params(right=False)
ax2.set_frame_on(False)

# Ajustando as propriedades do eixo Y da esquerda
plt.setp(ax1, xticks=[2002,2020], xticklabels=['2002', '2020'],
         yticks=df_agro_slope.iloc[0,:],
         yticklabels=[f'{str(valor)}%' if i!= 3 else f'{str(valor)}%\n\n' for i, valor in enumerate(df_agro_slope.iloc[0,:])])

# Ajustando as propriedades do eixo Y da direita
plt.setp(ax2, yticks=df_agro_slope.iloc[1,:],
         yticklabels=[f'{str(valor)}%' for i, valor in enumerate(df_agro_slope.iloc[1,:])])

# Ajustando propriedades dos dois eixos Y
for ax in (ax1, ax2):
    for i, item in enumerate(ax.get_yticklabels()):
        item.set_fontsize(14)
        item.set_fontweight('bold')
        item.set_color(cores[i])

# Ajustando propriedades do eixo X
ax1.xaxis.set_tick_params(labelsize=14, labelcolor=CINZA3)
ax1.spines['bottom'].set_color(CINZA3)

plt.show()

# %% [markdown]
# # Análises propostas

# %% [markdown]
# ### Questionamento 1 e tratamento dos dados

# %% [markdown]
# No setor de Administração, Defesa, Educação, Saúde Pública e Seguridade Social (ADESPSS), como estão distribuídos os valores adicionados por região, em valores relativos, dentro do período da base dos dados (2002 - 2020)?

# %%
# Selecionando os dados desejados
df_adespss = df_pib.copy()
df_adespss = df_adespss[['ano', 'regiao', 'va_adespss']]

# Agrupamento dos dados
df_adespss = pd.crosstab(index=df_adespss.ano,
                         columns=df_adespss.regiao,
                         values=df_adespss.va_adespss,
                         aggfunc='sum',
                         normalize='index')
df_adespss = round(df_adespss * 100, 2)
df_adespss.head()
# Out:
# regiao  Centro-Oeste  Nordeste  Norte  Sudeste    Sul
# ano
# 2002           15.24     19.25   7.27    45.80  12.44
# 2003           15.23     19.17   7.34    45.17  13.08
# 2004           16.03     19.03   7.45    44.67  12.82
# 2005           15.72     19.51   7.52    44.41  12.83
# 2006           16.02     19.99   7.68    43.70  12.61

# %%
df_adespss = df_adespss[['Sudeste', 'Nordeste', 'Centro-Oeste', 'Sul', 'Norte']]

# %% [markdown]
# ### Gerando gráfico de área

# %%
# Gerando área do gráfico
fig, ax = plt.subplots(figsize=(14,7))

# Definindo as cores do gráfico
cores = [AZUL3, VERMELHO2, LARANJA1, VERDE3, CINZA4]

# Gerando gráfico de área
df_adespss.plot(kind='area',
                stacked=True,
                color=cores,
                ax=ax,
                legend=False,
                xticks=range(2002,2021,2))

# Personalização do gráfico
ax.set_title('PIB relativo aos valores adicionados na ADESPSS',
             fontsize=18,
             color=CINZA1,
             loc='left')
ax.text(0.185, 0.98, 'De 2002 a 2020 (em %)',
        fontsize=12,
        color=CINZA3,
        transform=ax.transAxes,
        ha='right',
        va='center')
ax.set_xlabel('')
ax.set_ylabel('')
ax.xaxis.set_tick_params(labelsize=14,
                         labelcolor=CINZA2)
ax.yaxis.set_tick_params(labelsize=14,
                         labelcolor=CINZA2)
ax.set_frame_on(False)
ax.tick_params(axis='both', which='both', length=0)
plt.ylim(0,110)
ax.set_xbound(2001.7,2020)

# Anotando os nomes da regiões
reg = df_adespss.columns
y_pos = [21, 52, 70, 85, 95]
for i in range(len(reg)):
  ax.text(2011, y_pos[i], f'{reg[i]}', color = CINZA1, weight = "bold", fontsize = 14, ha="center", transform=ax.transData)

plt.show()

# %% [markdown]
# ### Questionamento 2 e tratamento dos dados

# %% [markdown]
# Qual foi a variação do PIB relativo à indústria nas regiões do Brasil nos anos de 2010, 2015 e 2020?

# %%
# Selecionando os dados desejados
df_ind = df_pib.copy()
df_ind = df_ind.query('ano == [2010, 2015, 2020]')[['ano', 'regiao', 'va_industria']]

# Agrupando os dados
df_ind = pd.crosstab(index=df_ind.ano,
                     columns=df_ind.regiao,
                     values=df_ind.va_industria,
                     aggfunc='sum',
                     normalize='index')
df_ind = round(df_ind * 100, 2)

df_ind.head()
# Out:
# regiao  Centro-Oeste  Nordeste  Norte  Sudeste    Sul
# ano
# 2010            6.06     11.60   6.49    58.79  17.07
# 2015            7.00     12.85   6.12    55.00  19.02
# 2020            7.35     12.21   9.28    52.00  19.17

# %% [markdown]
# ### Gerando gráfico de inclinação

# %% [markdown]
# Gerando função inicial

# %%
# Gerando função para criar gráfico de inclinação
def grafico_slope_ind():
    # Área do gráfico
    fig, ax1 = plt.subplots(figsize=(7,7))

    # Definindo as cores do gráfico
    cores = [VERDE3, VERMELHO2, CINZA4, AZUL3, LARANJA1]

    # Criando outro eixo Y que compartilha o mesmo eixo X
    ax2 = ax1.twinx()
    ax1.set_ylim([0,65])
    ax2.set_ylim([0,65])

    # Gerando gráfico de inclinação
    for i in range(5):
        # Adicionando o ponto inicial e final
        ax1.scatter(x=df_ind.index,
                    y=df_ind.iloc[:,i],
                    color = cores[i],
                    s=50)

        # Adicionando a inclinação
        ax1.plot(df_ind.index,
                 df_ind.iloc[:,i],
                 color = cores[i],
                 lw=3)

        # Adicionando as regiões no label
        ax1.text(x=2022.75,
                 y=df_ind.iloc[-1,i],
                 s=df_ind.columns[i],
                 fontsize=15,
                 fontweight='bold',
                 linespacing=1.5,
                 color=cores[i],
                 va='center')

    # Personalização do gráfico
    ax1.set_title('PIB relativo à indústria nas regiões do Brasil',
                  fontsize=18,
                  color=CINZA1,
                  loc='left',
                  pad=40)
    ax1.text(0.04, 1, 'Comparação entre os anos de 2002 e 2020 (em %)',
             transform=ax.transAxes,
             color=CINZA3,
             fontsize=12,
             ha='left',
             va='center')

    return ax1, ax2, cores

# %% [markdown]
# Personalizações finais para o gráfico

# %%
# Personalização do gráfico de inclinação para melhor visualização
ax1, ax2, cores = grafico_slope_ind()

# Retirando os ticks do eixo Y de ambos os lados e as bordas
ax1.tick_params(left=False)
ax1.spines[['top', 'left', 'right']].set_visible(False)
ax2.tick_params(right=False)
ax2.set_frame_on(False)

# Ajustando as propriedades do eixo Y da esquerda
plt.setp(ax1, xticks=[2010, 2015, 2020], xticklabels=['2010', '2015', '2020'],
         yticks=df_ind.iloc[0,:],
         yticklabels=[f'{str(valor)}%' if i!= 2 else f'{str(valor)}%\n\n' for i, valor in enumerate(df_ind.iloc[0,:])])

# Ajustando as propriedades do eixo Y da direita
plt.setp(ax2, yticks=df_ind.iloc[2,:],
         yticklabels=[f'{str(valor)}%' for i, valor in enumerate(df_ind.iloc[2,:])])

# Ajustando propriedades dos dois eixos Y
for ax in (ax1, ax2):
    for i, item in enumerate(ax.get_yticklabels()):
        item.set_fontsize(14)
        item.set_fontweight('bold')
        item.set_color(cores[i])

# Ajustando os pontos centrais
valores = df_ind.iloc[1,:].values
y_pos = [9, 15, 2, 52, 21]
for i in range(len(valores)):
    ax1.text(2015,
             y_pos[i],
             f'{valores[i]}%',
             weight='bold',
             fontsize=14,
             color=cores[i],
             ha='center',
             transform=ax.transData)

# Ajustando propriedades do eixo X
ax1.xaxis.set_tick_params(labelsize=14, labelcolor=CINZA3)
ax1.spines['bottom'].set_color(CINZA3)

plt.show()
